# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# original image
image = Image.open(r'C:\Users\shanmuga\OneDrive\Documents\mini project\mini project\UDD\train\train_image\DJI_0309.JPG')# Adjust path as needed
image = np.array(image)
plt.imshow(image)

# %%
label = Image.open(r'C:\Users\shanmuga\OneDrive\Documents\mini project\mini project\UDD\train\train_segmented\DJI_0309.JPG')# Adjust path as needed
label = np.array(label)
plt.imshow(label)

# %%
image.shape, label.shape
# Out:
# ((3000, 4000, 3), (3000, 4000, 3))

# %%
image.min(), image.max()
# Out:
# (0, 255)

# %%
label.min(), label.max()
# Out:
# (0, 255)

# %%
plt.figure(figsize = (9, 4))

plt.subplot(1, 2, 1)
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.imshow(label)

# %%
from glob import glob
images = sorted(glob(r'C:\Users\shanmuga\OneDrive\Documents\mini project\mini project\UDD\train\train_image\*.JPG'))# Adjust path as needed

# %%
len(images)
# Out:
# 120

# %%
labels = sorted(glob(r'C:\Users\shanmuga\OneDrive\Documents\mini project\mini project\UDD\val\val_image\*.JPG'))# Adjust path as needed

# %%
len(labels)
# Out:
# 40
